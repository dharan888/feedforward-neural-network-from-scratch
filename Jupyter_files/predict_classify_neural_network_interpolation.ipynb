# %%
import numpy as np
import matplotlib.pyplot as plt

from neural_network import Network
from layers import fcLayer, classLayer, regLayer 

np.random.seed(24)

x = np.expand_dims(np.linspace(-1,1,100),axis=0)
y = np.exp(x) + 0.05*np.random.randn(1,x.shape[1])
yhat = np.exp(x)

itr = np.concatenate((np.arange(0,50),np.arange(75,100)))
itt = np.arange(50,75)
x_train = x[:,itr]
y_train = y[:,itr]

x_test  = x[:,itt]
y_test  = y[:,itt]
plt.rcParams['figure.figsize'] = [10, 6]
plt.scatter(x_train.T, y_train.T,s=15, facecolors='b', edgecolors='none', label='noised training data')
plt.plot(x.T, yhat.T,'y--',label='function to fit')

reg_list = ['none']

nN = len(reg_list)
for i in range(1):
    reg = reg_list[0]
    fcnet = Network()
    fcnet.add(fcLayer(1, 10,'sigmoid'))
    fcnet.add(regLayer(10, 1,'linear'))
    fcnet.optimizer(eta=0.2, lamda=0.1, regularizer = reg) 
    # train
    [train_loss, test_loss] = fcnet.fit(x_train, y_train, x_test, y_test, batch_size = 4, epochs=2500)
    y_pred = fcnet.predict(x_test)
    #predict
    plt.scatter(x_test, y_pred, s=15, facecolors='none', edgecolors='r', label="predicted")
plt.xlabel("x")
plt.ylabel("y")
plt.title("exponential function - interpolating data")
plt.legend()
plt.savefig('exponential function_interpolating data.jpeg', dpi=800)
plt.show()
# Out:
# epoch 2500/2500   train_loss=0.001561   test_loss=0.000580

# %%
import numpy as np
import matplotlib.pyplot as plt

from neural_network import Network
from layers import fcLayer, classLayer, regLayer 

np.random.seed(24)

x = np.expand_dims(np.linspace(0,2*np.pi,100),axis=0)
y = np.sin(x) + 0.05*np.random.randn(1,x.shape[1])
yhat = np.sin(x)

itr = np.concatenate((np.arange(0,50),np.arange(75,100)))
itt = np.arange(50,75)
x_train = x[:,itr]
y_train = y[:,itr]

x_test  = x[:,itt]
y_test  = y[:,itt]
plt.rcParams['figure.figsize'] = [10, 6]
plt.scatter(x_train.T, y_train.T,s=15, facecolors='b', edgecolors='none', label='noised training data')
plt.plot(x.T, yhat.T,'y--',label='function to fit')

reg_list = ['none']

nN = len(reg_list)
for i in range(1):
    reg = reg_list[0]
    fcnet = Network()
    fcnet.add(fcLayer(1, 10,'tanh'))
    fcnet.add(regLayer(10, 1,'linear'))
    fcnet.optimizer(eta=0.2, lamda=0.1, regularizer = reg) 
    # train
    [train_loss, test_loss] = fcnet.fit(x_train, y_train, x_test, y_test, batch_size = 4, epochs=5000)
    y_pred = fcnet.predict(x_test)
    #predict
    plt.scatter(x_test, y_pred, s=15, facecolors='none', edgecolors='r', label="predicted")
plt.xlabel("x")
plt.ylabel("y")
plt.title("sinusoidal function - interpolating data")
plt.legend()
plt.savefig('sinusoidal function_interpolating data.jpeg', dpi=800)
plt.show()
# Out:
# epoch 5000/5000   train_loss=0.007093   test_loss=0.002427
